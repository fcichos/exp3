# %% [markdown]
# # Quantum Mechanics

# %% [markdown]
# <style>
# figure {
#   border: 1px #cccccc solid;
#   padding: 4px;
#   display: block;
#   margin-left: auto;
#   margin-right: auto;
# }
#
# figcaption {
#   background-color: #eeeeee;
#   color: black;
#   padding: 2px;
# }
# </style>
